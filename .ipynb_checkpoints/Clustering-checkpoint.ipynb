# %% [markdown]
# # Aplicação de *Clustering* e *Decision Tree*
#
# Esse notebook consiste na aplicação de técnicas de *Machine Learning* em dados de jogadores do  **[Campeonato Brasileiro](https://pt.wikipedia.org/wiki/Campeonato_Brasileiro_de_Futebol)**. As técnicas utilizadas foram **Clustering** e **Decision Tree**.

# %% [markdown]
# ## *Clustering*
#
# As técnicas de clusterização são muito importantes para termos *insights* sobre os dados disponíveis. Mesmo sem uma classificação exata dos dados, é possível que possamos tirar conclusões interessantes e reveladoras. Por exemplo, abaixo temos uma imagem que ilustra vários tipos de dados que podem ser agrupados por diferentes técnicas de clusterização.
# <img src="https://scikit-learn.org/stable/_images/sphx_glr_plot_linkage_comparison_0011.png" alt="Fonte: Scikit-learn" width="500"/>
#
# Assim, iremos utilizar os dados do [**Cartola FC**](https://globoesporte.globo.com/cartola-fc/) disponíveis [aqui](https://github.com/henriquepgomide/caRtola) para tentarmos agrupar os jogadores. Os dados são os valores do **Cartola FC** durate os anos de 2014 até 2017.
#
# **Iremos utilizar a versão dos dados disponíveis nesse repositório que já estão [limpos e prontos para análise](https://github.com/henriquepgomide/caRtola/blob/master/data/README.md#dados_agregados_limposcsv).**

# %% [markdown]
# ## Descrição dos Dados
#
# De acordo com o [fonte dos dados](https://github.com/henriquepgomide/caRtola/blob/master/data/README.md), no total são **17567** instancias e **77** características. Assim, cada linha da base de dados corresponde a uma rodada de uma jogador e as colunas as suas caracteríticas nessa rodada. Para uma visão completa de todas as 77 característica dê uma olhada na fonte, mas abaixo estão alguns dos atributos.
#
# | Características | Descrição          |
# |-----------------|--------------------|
# | Pontos          | pontuação do jogador                                      |
# | PontosMedia     | média da pontuação do jogador                             |
# | Preco           | preço do jogador                                          |
# | ...             | ...                                                       |
# | FS              | faltas sofridas                                           |
# | PE              | passes errados                                            |
# | A               | assistências                                              |
# | FT              | finalizações na trave                                     |
# | FD              | finalizações defendidas                                   |
# | FF              | finalizações para fora                                    |
# | G               | gols                                                      |
# | ano             | ano dos dados                                             |
# |...              |...                                                        |

# %% [markdown]
# ## Visualização dos Dados
# Inicialmente, vamos importar os dados e visualizá-los.

# %%
# imports
import pandas as pd 
data = pd.read_csv('dados_agregados_limpos.csv')
# brief look at the data
print(data.shape)
data.head(10)
# Out:
# (17567, 77)
#      A Apelido  AtletaID   CA   CV        ClubeID   DD   DP   FC   FD  \
# 0  0.0    Juan     36540  1.0  0.0  Internacional  0.0  0.0  2.0  0.0
# 1  0.0    Juan     36540  0.0  0.0  Internacional  0.0  0.0  2.0  1.0
# 2  0.0    Juan     36540  1.0  0.0  Internacional  0.0  0.0  2.0  0.0
# 3  0.0    Juan     36540  0.0  0.0  Internacional  0.0  0.0  0.0  1.0
# 4  0.0    Juan     36540  1.0  0.0  Internacional  0.0  0.0  5.0  0.0
# 5  0.0    Juan     36540  0.0  0.0  Internacional  0.0  0.0  0.0  0.0
# 6  0.0    Juan     36540  0.0  0.0  Internacional  0.0  0.0  1.0  0.0
# 7  0.0    Juan     36540  0.0  0.0  Internacional  0.0  0.0  1.0  1.0
# 8  0.0    Juan     36540  0.0  0.0  Internacional  0.0  0.0  0.0  0.0
# 9  1.0    Juan     36540  0.0  0.0  Internacional  0.0  0.0  0.0  0.0
#
#      ...      away.score.x   dia  home.attack  home.defend  home.score.x  mes  \
# 0    ...               0.0  19.0          0.0          0.0           1.0  4.0
# ...

# %% [markdown]
# De fato, podemos notar que temos **77 atributos** e **17567 instancias**.

# %% [markdown]
# ## Agrupar Jogadores - Posições Ideal
#
# Considere que um técnico está em dúvida sobre qual posição ele deveria escalar um dado jogador. Assim, queremos saber **"Qual a posição ideal de uma jogador segundo suas estastísticas?"**. Para isso, iremos **agrupar** os jogadores de acordo com as suas **métricas** e verificar quais as posições estão mais associadas a esses conjuntos.
#
# Antes, vamos modificar os dados iniciais de forma que cada linha represente o desempenho de um jogador na temporada (no caso o ano de 2017) e consideraremos a **média** de cada jogador nesse intervalo. Além disso, alguns dados **não estastísticos** dos jogodores serão desconsiderados. Ainda será removida a posição de técnico.

# %%
# Filter 2017 season and Remove 'tec' from columns 'Posicao'
data_2017 = data[(data['ano'] == 2017) & (data['Posicao'] != 'tec')]

# Categorical Features
cat_col = ['Status', 'variable']
dummies_df = pd.get_dummies(data_2017[cat_col])
data_2017 = pd.concat([data_2017, dummies_df], axis=1)
data_2017 = data_2017.drop(cat_col, axis=1)

# Numeric columns
columns = ['AtletaID','FS', 'PE', 'A', 'FT', 'FD', 'FF', 'G', 'I', 'PP', 'RB', 'FC', 'GC', 'CA', 'CV', 'SG', 'DD', 'DP', 'GS', 'Preco']
columns.extend(dummies_df.columns.values)

# Actual Position
data_positions = data_2017.groupby(by=['AtletaID']).max()['Posicao']

# Filters numeric values in the season 
data_2017_players = data_2017[columns].groupby(by=['AtletaID']).mean()

print(data_2017_players.shape)
print(len(data_positions))
data_2017_players.head()
# Out:
# (696, 26)
# 696
#                 FS        PE         A        FT        FD        FF    G  \
# AtletaID
# 36540     0.538462  1.076923  0.153846  0.076923  0.230769  0.461538  0.0
# 36612     0.727273  1.181818  0.181818  0.000000  0.000000  0.000000  0.0
# 37604     0.611111  2.277778  0.000000  0.055556  0.111111  0.000000  0.0
# 37607     0.785714  2.857143  0.142857  0.000000  0.214286  0.857143  0.0
# 37608     0.400000  2.200000  0.000000  0.000000  0.200000  0.000000  0.0
#
#                  I   PP        RB         ...           DP   GS     Preco  \
# AtletaID                                  ...
# 36540     0.000000  0.0  1.461538         ...          0.0  0.0  6.480769
# 36612     0.000000  0.0  0.454545         ...          0.0  0.0  7.266364
# 37604     0.000000  0.0  0.722222         ...          0.0  0.0  4.270556
# 37607     0.214286  0.0  1.357143         ...          0.0  0.0  5.448571
# 37608     0.000000  0.0  1.400000         ...          0.0  0.0  3.504000
#
# ...

# %% [markdown]
# Assim, ficamos com um total de **696 atletas** e o total de **26 estatísticas** ao longo da temporada.
#
# ### Redimensionar os Atributos
# Antes de aplicarmos os algoritmos de clusterização, devemos reduzir a escala dos atributos para que cada um tenha uma influência uniforme. Para isso, importamos e aplicamos a classes `StandardScaler` do `scikit-learn`.

# %%
# Imports
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Scaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data_2017_players)

# %% [markdown]
# ### KMeans
# Agora podemos aplicar o algoritmo *KMeans* para um total esperado de 5 grupos que representam as 5 posições dos jogadores.
# - Goleiro
# - Zagueiro
# - Lateral
# - Meia
# - Atacante

# %%
# Imports
from sklearn.cluster import KMeans

# Model with 5 clusters
kmeans_2017_5 = KMeans(n_clusters=5, random_state=42)

# Model grouping
labels_5 = kmeans_2017_5.fit_predict(scaled_data)

# %% [markdown]
# Podemos usar a **Matriz de Confusão** para avaliarmos o resultado.

# %%
# Creates a Dataframe for the possible positions
pos_df_5 = pd.DataFrame({'Class':labels_5, 'Position':data_positions})

ct_5 = pd.crosstab(pos_df_5['Class'], pos_df_5['Position'])
ct_5
# Out:
# Position  ata  gol  lat  mei  zag
# Class
# 0          84    4   18   88   21
# 1          56    0    5   37    0
# 2           0   40    0    0    0
# 3          30    5    9   31   17
# 4           8    0   71   96   76

# %% [markdown]
# Podemos ver que com exceção do **Goleiro**, os dados não foram suficientes para conseguirmos separar os jogadores entre suas respectivas posições. Ou ainda, que os jogadores de diferentes posições possuem métricas similares, como fica nítido nos casos  de **Atacante** e **Meia**. Talvez métodos de classificação mais genéricos pudessem ser mais eficientes.
#
# Então, considere que as posições dos jogadores sejam definidas por suas características, como descrito abaixo:
# - **Ataque**: Atacante
# - **Meio-Campo**: Meia
# - **Defensa**: Goleiro / Zagueiro / Lateral

# %%
# Relabeling function
def generic_positions(x):
    if (x == 'gol' or x == 'zag' or x == 'lat'):
        return 'Defesa'
    elif (x == 'ata'):
        return 'Ataque'
    else:
        return 'Meio-Campo'

# Currect Position
data_positions_3 = data_positions.apply(generic_positions)

# Model with 3 clusters
kmeans_2017_3 = KMeans(n_clusters=3, random_state=42)

# Model grouping
labels_3 = kmeans_2017_3.fit_predict(scaled_data)

# Creates a Dataframe for the possible positions
pos_df_3 = pd.DataFrame({'Class':labels_3, 'Position':data_positions_3})

ct_3 = pd.crosstab(pos_df_3['Class'], pos_df_3['Position'])
ct_3
# Out:
# Position  Ataque  Defesa  Meio-Campo
# Class
# 0             70     143         136
# 1            108      81         116
# 2              0      42           0

# %% [markdown]
# Podemos notar que os jogadores definitivamente defensivos podem ser definidos pela **classe 1**, enquanto que outras classes mostram jogadores com características mais híbridas entre **Defesa**, **Meio-Campo** e **Ataque**.
#
# **Assim, talvez essas classificações ajudem o treinador a colocar o jogador em uma posição mais defensiva/ofensiva.**

# %% [markdown]
# ### t-SNE
# Apesar do problema ter 19 dimensões, podemos usar técnicas para tentarmos visualizar o resultado em gráficos bidimensionais. Umas dessas técnicas é *t-SNE* e iremos aplicá-la abaixo.

# %%
# Labels
labels = pos_df['position'].astype('category').cat.codes

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# TSNE model
model = TSNE(learning_rate=100)
transformed = model.fit_transform(scaled_data)

xs = transformed[:, 0]
ys = transformed[:, 1]
plt.scatter(xs, ys, c=labels)
plt.show()

# %% [markdown]
# Pode-se notar que os dados são bastante sobrepostos, o que corrobora com os resultados obtidos no **KMeans**.

# %% [markdown]
# # *Decision Tree*
# Agora, vamos tentar criar um modelo de árvore de decisão que tente classificar a posição de um jogador de acordo com suas métricas. Resumidamente, a árvore de decisão é método usado tanto em classificação quanto em regressão que tenta criar uma sequencia de condições que melhor separe os dados.
#
# Como nas etapas anteriores já prepareamos os dados, podemos iniciar a sequencia para a criação de um modelo de *Machine Learning*. Iniciando pela divisão dos dados entre **Treinamento** e **Teste**.

# %%
from sklearn.model_selection import train_test_split

# Train / Test Split
X_train, X_test, y_train, y_test = train_test_split(scaled_data, labels, test_size=0.25, random_state=42)

print(X_train.shape)
print(X_test.shape)
# Out:
# (522, 26)
# (174, 26)

# %% [markdown]
# Assim, temos um total de **522** instancias para treinamento e **174** para validação.
#
# Finalmente, podemos criar e aplicar o **Modelo**.

# %%
from sklearn.tree import DecisionTreeClassifier

# Label binarizer necessary for 1 hot encode y
y_train = label_binarize(y_train, classes= [0, 1, 2, 3, 4])
y_test = label_binarize(y_test, classes= [0, 1, 2, 3, 4])

dtc = DecisionTreeClassifier(random_state=42)
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')

# %% [markdown]
# Agora podemos aplicar métricas ao modelo e analisar o seu desempenho. Essa métrica é a **Área sob a Curva ROC**.

# %%
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import label_binarize

# Predictions to train values
train_pred = dtc.predict(X_train)

# Predictions to test values
test_pred = dtc.predict(X_test)

# Errors
train_error = roc_auc_score(train_pred, y_train)
test_error = roc_auc_score(test_pred, y_test)

print("Error in train data: " + str(train_error))
print("Error in test data: " + str(test_error))
print("Max depth: " + str(dtc.tree_.max_depth))
# Out:
# Error in train data: 1.0
# Error in test data: 0.7901187381647625
# Max depth: 16

# %% [markdown]
# Nota-se que o modelo está ***Overfitting*** os dados de treinamento. Iremos tentar ajustar esse problema de Variância **reduzindo o tamanho da árvore** de 16 para no máximo 9.

# %%
dtc = DecisionTreeClassifier(random_state=42, max_depth=9)
dtc.fit(X_train, y_train)

# Predictions to train values
train_pred = dtc.predict(X_train)

# Predictions to test values
test_pred = dtc.predict(X_test)

# Errors
train_error = roc_auc_score(train_pred, y_train)
test_error = roc_auc_score(test_pred, y_test)

print("Error in train data: " + str(train_error))
print("Error in test data: " + str(test_error))
# Out:
# Error in train data: 0.9709368820794255
# Error in test data: 0.8303261795823248

# %% [markdown]
# Nota-se que a diferença de performance do modelo no treinamento e teste deminui, entranto ainda há *overfitting*. Vamos alterar outros **hiperparâmetros** do modelo em busca de resultados melhores. Outros parâmetros e seus significados estão mostrados abaixo.
#
# Parâmetro | Descrição
# ---|---
# `max_depth` | Profundidade máxima da árvore
# `min_sample_leaf` | Número mínimo de amostra para que seja um nó de folha
# `min_samples_split` | Número mínimo de amostra necessparios para dividir um nó interno

# %%
dtc = DecisionTreeClassifier(random_state=42, max_depth=9, min_samples_leaf=15, min_samples_split=5)
dtc.fit(X_train, y_train)

# Predictions to train values
train_pred = dtc.predict(X_train)

# Predictions to test values
test_pred = dtc.predict(X_test)

# Errors
train_error = roc_auc_score(train_pred, y_train)
test_error = roc_auc_score(test_pred, y_test)

print("Error in train data: " + str(train_error))
print("Error in test data: " + str(test_error))
# Out:
# Error in train data: 0.8921297813693982
# Error in test data: 0.8527951460149001

# %% [markdown]
# ## Conclusões
#
# Assim, conseguimos um resultado de **85% de Precisão** para um modelo relativamente simples de *Decision Tree*. Para aprimorar o modelo poderíamos tentar outras técnicas como *Features Engineering*, *GridSearch*, ou outros modelos. Entretanto, acabaríamos saindo do foco desse notebook.
